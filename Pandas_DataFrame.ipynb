# %% [markdown]
# <a href="https://colab.research.google.com/github/thasneema2414/AI_Machine_Test/blob/master/Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Weather_data.csv")

df
# Out:
#    Unnamed: 0       Day  Temp  Wind Speed  Event
# 0           0  1/1/2024    32           6   Rain
# 1           1  1/2/2024    35           7  Sunny
# 2           2  1/3/2024    28           2   Snow
# 3           3  1/4/2024    24           7   Snow
# 4           4  1/5/2024    32           4   Rain
# 5           5  1/6/2024    32           2  Sunny

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)
df
# Out:
#         Day  Temp  Wind Speed  Event
# 0  1/1/2024    32           6   Rain
# 1  1/2/2024    35           7  Sunny
# 2  1/3/2024    28           2   Snow
# 3  1/4/2024    24           7   Snow
# 4  1/5/2024    32           4   Rain
# 5  1/6/2024    32           2  Sunny

# %%
Weather_data = {
    "Day": ["1/1/2024", "1/2/2024", "1/3/2024", "1/4/2024", "1/5/2024", "1/6/2024"],
    "Temp": [32, 35, 28, 24, 32, 32],
    "Wind speed": [6, 7, 2, 7, 4, 2],
    "Event": ["Rain", "Sunny", "Snow", "Snow", "Rain", "Sunny"]
}

df = pd.DataFrame(Weather_data)
df
# Out:
#         Day  Temp  Wind speed  Event
# 0  1/1/2024    32           6   Rain
# 1  1/2/2024    35           7  Sunny
# 2  1/3/2024    28           2   Snow
# 3  1/4/2024    24           7   Snow
# 4  1/5/2024    32           4   Rain
# 5  1/6/2024    32           2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
rows, col = df.shape
print("rows = ", rows)
print("cols = ", col)
# Out:
# rows =  6
# cols =  4

# %%
df.head()
# Out:
#         Day  Temp  Wind speed  Event
# 0  1/1/2024    32           6   Rain
# 1  1/2/2024    35           7  Sunny
# 2  1/3/2024    28           2   Snow
# 3  1/4/2024    24           7   Snow
# 4  1/5/2024    32           4   Rain

# %%
df.head(2)
# Out:
#         Day  Temp  Wind speed  Event
# 0  1/1/2024    32           6   Rain
# 1  1/2/2024    35           7  Sunny

# %%
df.tail()
# Out:
#         Day  Temp  Wind speed  Event
# 1  1/2/2024    35           7  Sunny
# 2  1/3/2024    28           2   Snow
# 3  1/4/2024    24           7   Snow
# 4  1/5/2024    32           4   Rain
# 5  1/6/2024    32           2  Sunny

# %%
df.tail(2)
# Out:
#         Day  Temp  Wind speed  Event
# 4  1/5/2024    32           4   Rain
# 5  1/6/2024    32           2  Sunny

# %%
df[2:5]
# Out:
#         Day  Temp  Wind speed Event
# 2  1/3/2024    28           2  Snow
# 3  1/4/2024    24           7  Snow
# 4  1/5/2024    32           4  Rain

# %%
df[1:3]
# Out:
#         Day  Temp  Wind speed  Event
# 1  1/2/2024    35           7  Sunny
# 2  1/3/2024    28           2   Snow

# %%
df.columns
# Out:
# Index(['Day', 'Temp', 'Wind speed', 'Event'], dtype='object')

# %%
df.Day
# Out:
# 0    1/1/2024
# 1    1/2/2024
# 2    1/3/2024
# 3    1/4/2024
# 4    1/5/2024
# 5    1/6/2024
# Name: Day, dtype: object

# %%
df["Day"]
# Out:
# 0    1/1/2024
# 1    1/2/2024
# 2    1/3/2024
# 3    1/4/2024
# 4    1/5/2024
# 5    1/6/2024
# Name: Day, dtype: object

# %%
df[["Day", "Temp"]]
# Out:
#         Day  Temp
# 0  1/1/2024    32
# 1  1/2/2024    35
# 2  1/3/2024    28
# 3  1/4/2024    24
# 4  1/5/2024    32
# 5  1/6/2024    32

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv("/content/drive/MyDrive/Weather_data.csv")

df
# Out:
#    Unnamed: 0       Day  Temp  Wind Speed  Event
# 0           0  1/1/2024    32           6   Rain
# 1           1  1/2/2024    35           7  Sunny
# 2           2  1/3/2024    28           2   Snow
# 3           3  1/4/2024    24           7   Snow
# 4           4  1/5/2024    32           4   Rain
# 5           5  1/6/2024    32           2  Sunny

# %%
df.head()
# Out:
#    Unnamed: 0       Day  Temp  Wind Speed  Event
# 0           0  1/1/2024    32           6   Rain
# 1           1  1/2/2024    35           7  Sunny
# 2           2  1/3/2024    28           2   Snow
# 3           3  1/4/2024    24           7   Snow
# 4           4  1/5/2024    32           4   Rain

# %%
df.tail()
# Out:
#    Unnamed: 0       Day  Temp  Wind Speed  Event
# 1           1  1/2/2024    35           7  Sunny
# 2           2  1/3/2024    28           2   Snow
# 3           3  1/4/2024    24           7   Snow
# 4           4  1/5/2024    32           4   Rain
# 5           5  1/6/2024    32           2  Sunny

# %%
df['Temp']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    32
# Name: Temp, dtype: int64

# %%
df[['Day', 'Temp', 'Event']]
# Out:
#         Day  Temp  Event
# 0  1/1/2024    32   Rain
# 1  1/2/2024    35  Sunny
# 2  1/3/2024    28   Snow
# 3  1/4/2024    24   Snow
# 4  1/5/2024    32   Rain
# 5  1/6/2024    32  Sunny

# %%
df.isna()
# Out:
#    Unnamed: 0    Day   Temp  Wind Speed  Event
# 0       False  False  False       False  False
# 1       False  False  False       False  False
# 2       False  False  False       False  False
# 3       False  False  False       False  False
# 4       False  False  False       False  False
# 5       False  False  False       False  False

# %%
df.drop("Unnamed: 0", axis = 1, inplace = True)
df
# Out:
#         Day  Temp  Wind Speed  Event
# 0  1/1/2024    32           6   Rain
# 1  1/2/2024    35           7  Sunny
# 2  1/3/2024    28           2   Snow
# 3  1/4/2024    24           7   Snow
# 4  1/5/2024    32           4   Rain
# 5  1/6/2024    32           2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df.describe()
# Out:
#             Temp  Wind Speed
# count   6.000000    6.000000
# mean   30.500000    4.666667
# std     3.885872    2.338090
# min    24.000000    2.000000
# 25%    29.000000    2.500000
# 50%    32.000000    5.000000
# 75%    32.000000    6.750000
# max    35.000000    7.000000

# %%
row, columns = df.shape

# %%
row
# Out:
# 6

# %%
columns
# Out:
# 4

# %%
df.head(2)
# Out:
#         Day  Temp  Wind Speed  Event
# 0  1/1/2024    32           6   Rain
# 1  1/2/2024    35           7  Sunny

# %%
df.tail(2)
# Out:
#         Day  Temp  Wind Speed  Event
# 4  1/5/2024    32           4   Rain
# 5  1/6/2024    32           2  Sunny

# %%
df[2:4]
# Out:
#         Day  Temp  Wind Speed Event
# 2  1/3/2024    28           2  Snow
# 3  1/4/2024    24           7  Snow

# %%
df
# Out:
#         Day  Temp  Wind Speed  Event
# 0  1/1/2024    32           6   Rain
# 1  1/2/2024    35           7  Sunny
# 2  1/3/2024    28           2   Snow
# 3  1/4/2024    24           7   Snow
# 4  1/5/2024    32           4   Rain
# 5  1/6/2024    32           2  Sunny

# %%
df[0:3:2]
# Out:
#         Day  Temp  Wind Speed Event
# 0  1/1/2024    32           6  Rain
# 2  1/3/2024    28           2  Snow

# %%
df.columns
# Out:
# Index(['Day', 'Temp', 'Wind Speed', 'Event'], dtype='object')

# %%
df.Day
# Out:
# 0    1/1/2024
# 1    1/2/2024
# 2    1/3/2024
# 3    1/4/2024
# 4    1/5/2024
# 5    1/6/2024
# Name: Day, dtype: object

# %%
df['Day']
# Out:
# 0    1/1/2024
# 1    1/2/2024
# 2    1/3/2024
# 3    1/4/2024
# 4    1/5/2024
# 5    1/6/2024
# Name: Day, dtype: object

# %%
#max temp
df.Temp.max()
# Out:
# 35

# %%
df['Temp'].min()
# Out:
# 24

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2475ae27-40bf-41fb-89f9-4be090b002a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2475ae27-40bf-41fb-89f9-4be090b002a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'Weather_data.csv': b',Day,Temp,Wind Speed,Event\r\n0,1/1/2024,32,6,Rain\r\n1,1/2/2024,35,7,Sunny\r\n2,1/3/2024,28,2,Snow\r\n3,1/4/2024,24,7,Snow\r\n4,1/5/2024,32,4,Rain\r\n5,1/6/2024,32,2,Sunny\r\n'}

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['Weather_data.csv']))

# %%
df
# Out:
#    Unnamed: 0       Day  Temp  Wind Speed  Event
# 0           0  1/1/2024    32           6   Rain
# 1           1  1/2/2024    35           7  Sunny
# 2           2  1/3/2024    28           2   Snow
# 3           3  1/4/2024    24           7   Snow
# 4           4  1/5/2024    32           4   Rain
# 5           5  1/6/2024    32           2  Sunny
